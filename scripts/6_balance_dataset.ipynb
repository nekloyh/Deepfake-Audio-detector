# %%
import os
import shutil
import random
import hashlib
from pydub import AudioSegment
from pydub.silence import detect_silence
import hashlib
import numpy as np

random.seed(42)
np.random.seed(42)

# %%
RAW_DATASET_PATH = "F:\\Deepfake-Audio-Detector\\datasets\\raw_final_dataset"

def count_audio_needed_for_balance(set_type, base_dir = RAW_DATASET_PATH):
    folder_path_real = os.path.join(base_dir, set_type, "real")
    folder_path_fake = os.path.join(base_dir, set_type, "fake")
    
    if not os.path.exists(folder_path_real):
        print(f"Not found: {folder_path_real}")
        return 
    
    if not os.path.exists(folder_path_fake):
        print(f"Not found: {folder_path_fake}")
        return 
    
    real_file_count = sum(1 for f in os.listdir(folder_path_real))
    fake_file_count = sum(1 for f in os.listdir(folder_path_fake))
    print(f"{set_type.upper()} \\ real\t: {real_file_count} files")
    print(f"{set_type.upper()} \\ fake\t: {fake_file_count} files")
    print(f"Need {real_file_count - fake_file_count} to balance {set_type.upper()} data")
    
    return real_file_count - fake_file_count
    
train_needed = count_audio_needed_for_balance("train")
val_needed = count_audio_needed_for_balance("val")
test_needed = count_audio_needed_for_balance("test")
# Out:
# TRAIN \ real	: 51448 files
# TRAIN \ fake	: 20439 files
# Need 31009 to balance TRAIN data
# VAL \ real	: 3498 files
# VAL \ fake	: 1216 files
# Need 2282 to balance VAL data
# TEST \ real	: 7033 files
# TEST \ fake	: 2370 files
# Need 4663 to balance TEST data

# %%
DFADD_PATH = "F:\\Deepfake-Audio-Detector\\datasets\\dfadd-dataset\\"
AUDIO_FILE_EXTENSIONS = [".wav", ".flac", ".mp3", ".m4a"]

DFADD_STD_DIR = "F:\\Deepfake-Audio-Detector\\datasets\\dfadd_standardized\\"
CURRENT_DIR = "/kaggle/working/standardized_3s"

def get_audio_files(directory, extensions):
    return [f for f in os.listdir(directory) if any(f.endswith(ext) for ext in extensions)]

DFADD_FAKE_PATH = os.path.join(DFADD_PATH, "fake")
fake_files = get_audio_files(DFADD_FAKE_PATH, AUDIO_FILE_EXTENSIONS)
print(f"DFADD Real Samples: {len(fake_files)}")
# Out:
# DFADD Real Samples: 163500

# %%
# Step 2: Balence data utils

# Silence checker
def is_mostly_silent(
    audio_segment, threshold_db=-40, min_silence_len_ms=300, silence_ratio=0.7
):
    try:
        silent_ranges = detect_silence(
            audio_segment,
            min_silence_len=min_silence_len_ms,
            silence_thresh=threshold_db,
        )
        total_silence_ms = sum((end - start) for start, end in silent_ranges)
        return (total_silence_ms / len(audio_segment)) > silence_ratio
    except Exception:
        return False

# Dulicated checker
def compute_audio_hash(audio_segment):
    raw_data = audio_segment.raw_data
    return hashlib.md5(raw_data).hexdigest()

def sample_and_standardize(
    source_dir,
    output_dir,
    target_sr=16000,
    target_duration=3.0,
    max_chunk=4.5,
    desired_count=40000,
    max_trials=500000,
    silence_threshold_db = -40,
    min_silence_len_ms = 300,
    silence_ratio=0.7
):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    SUPPORTED_EXTENSIONS = (".wav", ".flac", ".mp3", ".m4a")
    files = [f for f in os.listdir(source_dir) if f.lower().endswith(SUPPORTED_EXTENSIONS)]
    seen_hashes = set()
    collected = 0
    trials = 0
    target_len_ms = int(target_duration * 1000)
    max_chunk_ms = int(max_chunk * 1000)

    while collected < desired_count and trials < max_trials:
        trials += 1
        file = random.choice(files)
        file_path = os.path.join(source_dir, file)
        
        try:
            audio = AudioSegment.from_file(file_path)
            audio = audio.set_frame_rate(target_sr).set_channels(1)
            audio_len_ms = len(audio)
            if audio_len_ms < target_len_ms:
                continue

            segment = None
            if audio_len_ms <= max_chunk_ms:
                max_start = audio_len_ms - target_len_ms
                if max_start <= 0:
                    continue
                start_ms = random.randint(0, max_start)
                segment = audio[start_ms : start_ms + target_len_ms]
            else:
                chunk_start_ms = random.randint(0, audio_len_ms - max_chunk_ms)
                chunk = audio[chunk_start_ms : chunk_start_ms + max_chunk_ms]
                if is_mostly_silent(
                    chunk, 
                    threshold_db=silence_threshold_db, 
                    min_silence_len_ms=min_silence_len_ms,
                    silence_ratio=silence_ratio
                ):
                    continue
                if len(chunk) < target_len_ms:
                    continue

                max_start_in_chunk = len(chunk) - target_len_ms
                start_in_chunk = random.randint(0, max_start_in_chunk)
                segment = chunk[start_in_chunk : start_in_chunk + target_len_ms]

            if segment is None:
                continue
            if is_mostly_silent(
                segment,
                threshold_db=silence_threshold_db,
                min_silence_len_ms=min_silence_len_ms,
                silence_ratio=silence_ratio,
            ):
                continue
            if len(segment) > target_len_ms:
                segment = segment[:target_len_ms]
            elif len(segment) < target_len_ms:
                padding_needed = target_len_ms - len(segment)
                segment = (
                    segment.set_frame_rate(target_sr)
                    .set_channels(1)
                    .append(
                        AudioSegment.silent(
                            duration=padding_needed, frame_rate=target_sr
                        ),
                        crossfade=0,
                    )
                )
                
            segment_hash = compute_audio_hash(segment)
            if segment_hash in seen_hashes:
                continue

            seen_hashes.add(segment_hash)
            original_file_base = os.path.splitext(file)[0]
            output_name = f"{original_file_base}_s{collected + 1}.wav"
            output_path = os.path.join(output_dir, output_name)
            segment.export(output_path, format="wav")
            collected += 1
            if collected % 100 == 0:
                print(f"✅ Collected: {collected}/{desired_count}, Trials: {trials}")
        except Exception:
            print(f"❌ Error with {file_path}")

    print(f"\n🎯 Done! Collected {collected} audio segments out of {trials} trials.")
    if collected < desired_count:
        print(
            f"Warning: Could not collect desired count. Only {collected} segments were gathered."
        )

# %%
sample_and_standardize(
    source_dir="F:\\Deepfake-Audio-Detector\\datasets\\dfadd-dataset\\fake",
    output_dir="F:\\Deepfake-Audio-Detector\\datasets\\dfadd-standardized",
    target_duration=3.0,
    max_chunk=4.5,
    desired_count=40000,
    max_trials=500000,
    silence_threshold_db=-40,
    min_silence_len_ms=300,
    silence_ratio=0.7
)
# Out:
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p360_006_pflow.wav
# ✅ Collected: 100/40000, Trials: 101
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p238_069_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p374_261_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p310_197_pflow.wav
# ✅ Collected: 200/40000, Trials: 204
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p243_079_pflow.wav
# ✅ Collected: 300/40000, Trials: 305
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p248_220_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p347_219_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p306_253_pflow.wav
# ✅ Collected: 400/40000, Trials: 408
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p294_252_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p225_149_pflow.wav
# ✅ Collected: 500/40000, Trials: 510
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p335_263_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p234_283_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p304_299_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p376_243_pflow.wav
# ✅ Collected: 600/40000, Trials: 615
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p271_218_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p298_184_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p333_085_pflow.wav
# ✅ Collected: 700/40000, Trials: 718
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p279_277_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p248_124_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p253_009_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p312_100_pflow.wav
# ✅ Collected: 800/40000, Trials: 822
# ✅ Collected: 900/40000, Trials: 922
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p260_087_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p323_212_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p252_060_pflow.wav
# ✅ Collected: 1000/40000, Trials: 1025
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p340_047_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p301_014_pflow.wav
# ✅ Collected: 1100/40000, Trials: 1127
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p250_030_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p308_094_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p251_141_pflow.wav
# ✅ Collected: 1200/40000, Trials: 1230
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p241_241_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p284_283_pflow.wav
# ✅ Collected: 1300/40000, Trials: 1332
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p284_263_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p241_152_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p273_010_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p272_021_pflow.wav
# ✅ Collected: 1400/40000, Trials: 1436
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p317_199_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p283_023_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p238_134_pflow.wav
# ✅ Collected: 1500/40000, Trials: 1539
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p292_145_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p374_193_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p298_079_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p343_050_pflow.wav
# ✅ Collected: 1600/40000, Trials: 1643
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p234_268_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p227_080_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p254_256_pflow.wav
# ✅ Collected: 1700/40000, Trials: 1746
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p341_242_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p284_115_pflow.wav
# ✅ Collected: 1800/40000, Trials: 1848
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p225_287_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p227_206_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p334_204_pflow.wav
# ✅ Collected: 1900/40000, Trials: 1951
# ✅ Collected: 2000/40000, Trials: 2051
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p248_104_pflow.wav
# ✅ Collected: 2100/40000, Trials: 2152
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p334_133_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p303_084_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p312_012_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p279_251_pflow.wav
# ✅ Collected: 2200/40000, Trials: 2256
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p279_092_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p364_148_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p264_033_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p284_292_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p303_099_pflow.wav
# ✅ Collected: 2300/40000, Trials: 2361
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p362_198_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p298_012_pflow.wav
# ✅ Collected: 2400/40000, Trials: 2463
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p284_193_pflow.wav
# ✅ Collected: 2500/40000, Trials: 2564
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p237_015_pflow.wav
# ✅ Collected: 2600/40000, Trials: 2665
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p374_025_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p282_160_pflow.wav
# ✅ Collected: 2700/40000, Trials: 2767
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p248_272_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p237_093_pflow.wav
# ✅ Collected: 2800/40000, Trials: 2869
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p269_205_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p306_240_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p241_235_pflow.wav
# ✅ Collected: 2900/40000, Trials: 2972
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p270_016_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p323_048_pflow.wav
# ✅ Collected: 3000/40000, Trials: 3074
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p279_177_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p308_245_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p314_002_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p329_155_pflow.wav
# ✅ Collected: 3100/40000, Trials: 3178
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p294_164_pflow.wav
# ✅ Collected: 3200/40000, Trials: 3280
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p284_121_pflow.wav
# ✅ Collected: 3300/40000, Trials: 3381
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p286_106_pflow.wav
# ✅ Collected: 3400/40000, Trials: 3482
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p271_145_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p292_287_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p284_162_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p364_055_pflow.wav
# ✅ Collected: 3500/40000, Trials: 3586
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p243_265_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p326_234_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p279_141_pflow.wav
# ✅ Collected: 3600/40000, Trials: 3689
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p361_072_pflow.wav
# ✅ Collected: 3700/40000, Trials: 3790
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p265_037_pflow.wav
# ✅ Collected: 3800/40000, Trials: 3891
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p286_019_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p376_161_pflow.wav
# ✅ Collected: 3900/40000, Trials: 3993
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p243_280_pflow.wav
# ✅ Collected: 4000/40000, Trials: 4094
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p238_268_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p232_253_pflow.wav
# ✅ Collected: 4100/40000, Trials: 4196
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p312_237_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p313_072_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p286_232_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p255_025_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p310_158_pflow.wav
# ✅ Collected: 4200/40000, Trials: 4301
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p256_273_pflow.wav
# ✅ Collected: 4300/40000, Trials: 4402
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p343_103_pflow.wav
# ✅ Collected: 4400/40000, Trials: 4503
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p316_283_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p329_059_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p326_025_pflow.wav
# ✅ Collected: 4500/40000, Trials: 4606
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p284_250_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p260_253_pflow.wav
# ✅ Collected: 4600/40000, Trials: 4708
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p374_017_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p347_043_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p329_107_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p282_117_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p253_183_pflow.wav
# ✅ Collected: 4700/40000, Trials: 4813
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p323_183_pflow.wav
# ✅ Collected: 4800/40000, Trials: 4914
# ✅ Collected: 4900/40000, Trials: 5014
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p303_105_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p307_248_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p298_121_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p263_245_pflow.wav
# ✅ Collected: 5000/40000, Trials: 5118
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p294_162_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p310_024_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p374_088_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p374_086_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p248_175_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p278_061_pflow.wav
# ✅ Collected: 5100/40000, Trials: 5224
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p238_062_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p298_102_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p278_027_pflow.wav
# ✅ Collected: 5200/40000, Trials: 5327
# ✅ Collected: 5300/40000, Trials: 5427
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p272_282_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p376_251_pflow.wav
# ✅ Collected: 5400/40000, Trials: 5529
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p297_202_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p323_068_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p376_266_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p301_215_pflow.wav
# ✅ Collected: 5500/40000, Trials: 5633
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p243_130_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p339_198_pflow.wav
# ✅ Collected: 5600/40000, Trials: 5735
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p376_139_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p254_117_pflow.wav
# ✅ Collected: 5700/40000, Trials: 5837
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p260_059_pflow.wav
# ✅ Collected: 5800/40000, Trials: 5938
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p347_244_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p284_024_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p343_079_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p303_155_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p298_214_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p267_049_pflow.wav
# ✅ Collected: 5900/40000, Trials: 6044
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p343_145_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p243_129_pflow.wav
# ✅ Collected: 6000/40000, Trials: 6146
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p302_007_pflow.wav
# ✅ Collected: 6100/40000, Trials: 6247
# ✅ Collected: 6200/40000, Trials: 6347
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p306_222_pflow.wav
# ✅ Collected: 6300/40000, Trials: 6448
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p226_184_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p232_234_pflow.wav
# ✅ Collected: 6400/40000, Trials: 6550
# ✅ Collected: 6500/40000, Trials: 6650
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p335_258_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p335_173_pflow.wav
# ✅ Collected: 6600/40000, Trials: 6753
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p271_055_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p299_013_pflow.wav
# ✅ Collected: 6700/40000, Trials: 6855
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p316_043_pflow.wav
# ✅ Collected: 6800/40000, Trials: 6956
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p260_082_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p265_043_pflow.wav
# ✅ Collected: 6900/40000, Trials: 7058
# ✅ Collected: 7000/40000, Trials: 7158
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p260_084_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p376_074_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p263_241_pflow.wav
# ✅ Collected: 7100/40000, Trials: 7261
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p307_145_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p280_262_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p248_130_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p303_031_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p310_158_pflow.wav
# ✅ Collected: 7200/40000, Trials: 7366
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p292_030_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p316_056_pflow.wav
# ✅ Collected: 7300/40000, Trials: 7468
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p300_053_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p304_054_pflow.wav
# ✅ Collected: 7400/40000, Trials: 7570
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p246_115_pflow.wav
# ✅ Collected: 7500/40000, Trials: 7671
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p273_059_pflow.wav
# ✅ Collected: 7600/40000, Trials: 7772
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p288_253_pflow.wav
# ✅ Collected: 7700/40000, Trials: 7873
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p336_207_pflow.wav
# ✅ Collected: 7800/40000, Trials: 7974
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p278_194_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p301_269_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p273_082_pflow.wav
# ✅ Collected: 7900/40000, Trials: 8077
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p251_226_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p257_150_pflow.wav
# ✅ Collected: 8000/40000, Trials: 8179
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p227_182_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p303_081_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p268_009_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p297_202_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p374_171_pflow.wav
# ✅ Collected: 8100/40000, Trials: 8284
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p284_058_pflow.wav
# ✅ Collected: 8200/40000, Trials: 8385
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p360_131_pflow.wav
# ✅ Collected: 8300/40000, Trials: 8486
# ✅ Collected: 8400/40000, Trials: 8586
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p339_114_pflow.wav
# ✅ Collected: 8500/40000, Trials: 8688
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p238_279_pflow.wav
# ✅ Collected: 8600/40000, Trials: 8789
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p246_210_pflow.wav
# ✅ Collected: 8700/40000, Trials: 8890
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p292_227_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p364_114_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p272_120_pflow.wav
# ✅ Collected: 8800/40000, Trials: 8993
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p335_017_pflow.wav
# ✅ Collected: 8900/40000, Trials: 9094
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p330_083_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p316_224_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p243_101_pflow.wav
# ✅ Collected: 9000/40000, Trials: 9197
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p258_094_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p259_023_pflow.wav
# ✅ Collected: 9100/40000, Trials: 9299
# ✅ Collected: 9200/40000, Trials: 9399
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p347_139_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p227_034_pflow.wav
# ✅ Collected: 9300/40000, Trials: 9501
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p303_143_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p376_237_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p254_254_pflow.wav
# ✅ Collected: 9400/40000, Trials: 9604
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p269_103_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p294_053_pflow.wav
# ✅ Collected: 9500/40000, Trials: 9706
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p238_138_pflow.wav
# ✅ Collected: 9600/40000, Trials: 9807
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p306_253_pflow.wav
# ✅ Collected: 9700/40000, Trials: 9908
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p317_137_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p286_179_pflow.wav
# ✅ Collected: 9800/40000, Trials: 10010
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p314_163_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p243_038_pflow.wav
# ✅ Collected: 9900/40000, Trials: 10112
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p316_153_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p244_225_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p317_276_pflow.wav
# ✅ Collected: 10000/40000, Trials: 10215
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p237_186_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p333_049_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p330_180_pflow.wav
# ✅ Collected: 10100/40000, Trials: 10318
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p347_274_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p308_075_pflow.wav
# ✅ Collected: 10200/40000, Trials: 10420
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p278_232_pflow.wav
# ✅ Collected: 10300/40000, Trials: 10521
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p255_059_pflow.wav
# ✅ Collected: 10400/40000, Trials: 10622
# ✅ Collected: 10500/40000, Trials: 10722
# ✅ Collected: 10600/40000, Trials: 10822
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p275_210_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p298_208_pflow.wav
# ✅ Collected: 10700/40000, Trials: 10924
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p335_168_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p308_171_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p345_194_pflow.wav
# ✅ Collected: 10800/40000, Trials: 11028
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p361_255_pflow.wav
# ✅ Collected: 10900/40000, Trials: 11129
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p326_234_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p268_076_pflow.wav
# ✅ Collected: 11000/40000, Trials: 11231
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p280_157_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p251_233_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p228_171_pflow.wav
# ✅ Collected: 11100/40000, Trials: 11334
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\s5_293_pflow.wav
# ✅ Collected: 11200/40000, Trials: 11435
# ✅ Collected: 11300/40000, Trials: 11535
# ✅ Collected: 11400/40000, Trials: 11635
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p335_278_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p376_170_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p364_264_pflow.wav
# ✅ Collected: 11500/40000, Trials: 11738
# ✅ Collected: 11600/40000, Trials: 11838
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p287_004_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p315_247_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p228_083_pflow.wav
# ✅ Collected: 11700/40000, Trials: 11941
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p225_181_pflow.wav
# ✅ Collected: 11800/40000, Trials: 12042
# ✅ Collected: 11900/40000, Trials: 12142
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p263_150_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p267_049_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p343_268_pflow.wav
# ✅ Collected: 12000/40000, Trials: 12245
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p240_232_pflow.wav
# ✅ Collected: 12100/40000, Trials: 12346
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p253_266_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p314_206_pflow.wav
# ✅ Collected: 12200/40000, Trials: 12448
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p230_144_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p341_092_pflow.wav
# ✅ Collected: 12300/40000, Trials: 12550
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p279_153_pflow.wav
# ✅ Collected: 12400/40000, Trials: 12651
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p351_246_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p343_128_pflow.wav
# ✅ Collected: 12500/40000, Trials: 12753
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p351_232_pflow.wav
# ✅ Collected: 12600/40000, Trials: 12854
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p333_249_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p313_116_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p260_235_pflow.wav
# ✅ Collected: 12700/40000, Trials: 12957
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p307_267_pflow.wav
# ✅ Collected: 12800/40000, Trials: 13058
# ✅ Collected: 12900/40000, Trials: 13158
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p227_152_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p278_243_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p297_209_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p303_188_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p226_233_pflow.wav
# ✅ Collected: 13000/40000, Trials: 13263
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p376_082_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p374_025_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p279_148_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p376_245_pflow.wav
# ✅ Collected: 13100/40000, Trials: 13367
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p362_173_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p278_070_pflow.wav
# ✅ Collected: 13200/40000, Trials: 13469
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p271_006_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p276_247_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p315_276_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p330_209_pflow.wav
# ✅ Collected: 13300/40000, Trials: 13573
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p305_191_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p246_260_pflow.wav
# ✅ Collected: 13400/40000, Trials: 13675
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p292_187_pflow.wav
# ✅ Collected: 13500/40000, Trials: 13776
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p237_028_pflow.wav
# ✅ Collected: 13600/40000, Trials: 13877
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p323_112_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p363_028_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p261_120_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p243_062_pflow.wav
# ✅ Collected: 13700/40000, Trials: 13981
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p343_030_pflow.wav
# ✅ Collected: 13800/40000, Trials: 14082
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p313_288_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p298_086_pflow.wav
# ✅ Collected: 13900/40000, Trials: 14184
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p347_124_pflow.wav
# ✅ Collected: 14000/40000, Trials: 14285
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p228_192_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p360_001_pflow.wav
# ✅ Collected: 14100/40000, Trials: 14387
# ✅ Collected: 14200/40000, Trials: 14487
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p284_250_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p313_104_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p310_145_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p313_288_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p248_059_pflow.wav
# ✅ Collected: 14300/40000, Trials: 14592
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p336_197_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p294_176_pflow.wav
# ✅ Collected: 14400/40000, Trials: 14694
# ✅ Collected: 14500/40000, Trials: 14794
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p234_014_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p364_181_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p231_163_pflow.wav
# ✅ Collected: 14600/40000, Trials: 14897
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p265_016_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p231_300_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p239_017_pflow.wav
# ✅ Collected: 14700/40000, Trials: 15000
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p248_238_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p347_120_pflow.wav
# ✅ Collected: 14800/40000, Trials: 15102
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p248_137_pflow.wav
# ✅ Collected: 14900/40000, Trials: 15203
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p286_148_pflow.wav
# ✅ Collected: 15000/40000, Trials: 15304
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p239_023_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p288_003_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p345_141_pflow.wav
# ✅ Collected: 15100/40000, Trials: 15407
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p343_065_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p329_136_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p266_289_pflow.wav
# ✅ Collected: 15200/40000, Trials: 15510
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p243_223_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p250_093_pflow.wav
# ✅ Collected: 15300/40000, Trials: 15612
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p308_110_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p297_299_pflow.wav
# ✅ Collected: 15400/40000, Trials: 15714
# ✅ Collected: 15500/40000, Trials: 15814
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p316_094_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p297_249_pflow.wav
# ✅ Collected: 15600/40000, Trials: 15916
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p238_204_pflow.wav
# ✅ Collected: 15700/40000, Trials: 16017
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p248_018_pflow.wav
# ✅ Collected: 15800/40000, Trials: 16118
# ✅ Collected: 15900/40000, Trials: 16218
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p256_200_pflow.wav
# ✅ Collected: 16000/40000, Trials: 16319
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p233_250_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p306_125_pflow.wav
# ✅ Collected: 16100/40000, Trials: 16421
# ✅ Collected: 16200/40000, Trials: 16521
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p329_085_pflow.wav
# ✅ Collected: 16300/40000, Trials: 16622
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p340_075_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p284_186_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p303_150_pflow.wav
# ✅ Collected: 16400/40000, Trials: 16725
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p286_150_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p315_197_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\s5_115_pflow.wav
# ✅ Collected: 16500/40000, Trials: 16828
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p248_166_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p271_197_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p317_119_pflow.wav
# ✅ Collected: 16600/40000, Trials: 16931
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p305_191_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p272_260_pflow.wav
# ✅ Collected: 16700/40000, Trials: 17033
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p259_147_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p312_136_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p260_178_pflow.wav
# ✅ Collected: 16800/40000, Trials: 17136
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p313_180_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p313_145_pflow.wav
# ✅ Collected: 16900/40000, Trials: 17238
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p272_165_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p232_062_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p285_263_pflow.wav
# ✅ Collected: 17000/40000, Trials: 17341
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p287_239_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p272_030_pflow.wav
# ✅ Collected: 17100/40000, Trials: 17443
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p305_105_pflow.wav
# ✅ Collected: 17200/40000, Trials: 17544
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p318_230_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p281_028_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p241_251_pflow.wav
# ✅ Collected: 17300/40000, Trials: 17647
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p245_198_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p268_297_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p316_260_pflow.wav
# ✅ Collected: 17400/40000, Trials: 17750
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p271_071_pflow.wav
# ✅ Collected: 17500/40000, Trials: 17851
# ✅ Collected: 17600/40000, Trials: 17951
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p336_298_pflow.wav
# ✅ Collected: 17700/40000, Trials: 18052
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p273_211_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p360_074_pflow.wav
# ✅ Collected: 17800/40000, Trials: 18154
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p374_182_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p246_131_pflow.wav
# ✅ Collected: 17900/40000, Trials: 18256
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p306_083_pflow.wav
# ✅ Collected: 18000/40000, Trials: 18357
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p334_063_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p308_282_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p308_287_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p298_052_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p351_071_pflow.wav
# ✅ Collected: 18100/40000, Trials: 18462
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p333_050_pflow.wav
# ✅ Collected: 18200/40000, Trials: 18563
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p347_069_pflow.wav
# ✅ Collected: 18300/40000, Trials: 18664
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p285_062_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p303_167_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p306_125_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p266_275_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p249_276_pflow.wav
# ✅ Collected: 18400/40000, Trials: 18769
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p248_284_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p255_059_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p310_145_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p227_069_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p262_099_pflow.wav
# ✅ Collected: 18500/40000, Trials: 18874
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p376_126_pflow.wav
# ✅ Collected: 18600/40000, Trials: 18975
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p343_297_pflow.wav
# ✅ Collected: 18700/40000, Trials: 19076
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p263_052_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p279_196_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p312_276_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p308_077_pflow.wav
# ✅ Collected: 18800/40000, Trials: 19180
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p275_137_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p261_175_pflow.wav
# ✅ Collected: 18900/40000, Trials: 19282
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p345_208_pflow.wav
# ✅ Collected: 19000/40000, Trials: 19383
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p249_253_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p239_246_pflow.wav
# ✅ Collected: 19100/40000, Trials: 19485
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p336_073_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p312_098_pflow.wav
# ✅ Collected: 19200/40000, Trials: 19587
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p343_269_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p336_144_pflow.wav
# ✅ Collected: 19300/40000, Trials: 19689
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p266_053_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p260_012_pflow.wav
# ✅ Collected: 19400/40000, Trials: 19791
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p336_234_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p314_296_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p249_253_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p253_266_pflow.wav
# ✅ Collected: 19500/40000, Trials: 19895
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p376_011_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p288_177_pflow.wav
# ✅ Collected: 19600/40000, Trials: 19997
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p347_104_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p261_213_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p271_225_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p260_209_pflow.wav
# ✅ Collected: 19700/40000, Trials: 20101
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p292_062_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p292_037_pflow.wav
# ✅ Collected: 19800/40000, Trials: 20203
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p273_281_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p303_015_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p347_252_pflow.wav
# ✅ Collected: 19900/40000, Trials: 20306
# ✅ Collected: 20000/40000, Trials: 20406
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p278_026_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p284_071_pflow.wav
# ✅ Collected: 20100/40000, Trials: 20508
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p278_009_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p260_175_pflow.wav
# ✅ Collected: 20200/40000, Trials: 20610
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p282_143_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p238_300_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p306_117_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p280_186_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p254_087_pflow.wav
# ✅ Collected: 20300/40000, Trials: 20715
# ✅ Collected: 20400/40000, Trials: 20815
# ✅ Collected: 20500/40000, Trials: 20915
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p243_265_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p271_294_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p230_139_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p364_183_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p277_246_pflow.wav
# ✅ Collected: 20600/40000, Trials: 21020
# ✅ Collected: 20700/40000, Trials: 21120
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p376_243_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p293_192_pflow.wav
# ✅ Collected: 20800/40000, Trials: 21222
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p299_034_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p259_023_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p347_139_pflow.wav
# ✅ Collected: 20900/40000, Trials: 21325
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p266_053_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p255_107_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p330_197_pflow.wav
# ✅ Collected: 21000/40000, Trials: 21428
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p272_165_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p280_285_pflow.wav
# ✅ Collected: 21100/40000, Trials: 21530
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p298_079_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p288_021_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p285_227_pflow.wav
# ✅ Collected: 21200/40000, Trials: 21633
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p376_034_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p308_287_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p260_287_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p374_234_pflow.wav
# ✅ Collected: 21300/40000, Trials: 21737
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p340_214_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p261_164_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p363_026_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p303_055_pflow.wav
# ✅ Collected: 21400/40000, Trials: 21841
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p340_087_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p240_093_pflow.wav
# ✅ Collected: 21500/40000, Trials: 21943
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p278_070_pflow.wav
# ✅ Collected: 21600/40000, Trials: 22044
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p238_063_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p283_023_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p301_183_pflow.wav
# ✅ Collected: 21700/40000, Trials: 22147
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p294_192_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p326_176_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p364_055_pflow.wav
# ✅ Collected: 21800/40000, Trials: 22251
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p306_007_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p275_039_pflow.wav
# ✅ Collected: 21900/40000, Trials: 22353
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p287_222_pflow.wav
# ✅ Collected: 22000/40000, Trials: 22454
# ✅ Collected: 22100/40000, Trials: 22554
# ✅ Collected: 22200/40000, Trials: 22654
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p254_266_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p287_119_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p260_106_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p292_106_pflow.wav
# ...
# ✅ Collected: 32900/40000, Trials: 33589
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p362_072_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p303_037_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p316_257_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p268_039_pflow.wav
# ✅ Collected: 33000/40000, Trials: 33693
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p268_297_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p241_241_pflow.wav
# ✅ Collected: 33100/40000, Trials: 33795
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p363_188_pflow.wav
# ✅ Collected: 33200/40000, Trials: 33896
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p308_291_pflow.wav
# ✅ Collected: 33300/40000, Trials: 33997
# ✅ Collected: 33400/40000, Trials: 34097
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p248_138_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p297_159_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p226_233_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p341_061_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p294_192_pflow.wav
# ✅ Collected: 33500/40000, Trials: 34202
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p267_164_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p330_223_pflow.wav
# ✅ Collected: 33600/40000, Trials: 34304
# ✅ Collected: 33700/40000, Trials: 34404
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p264_067_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p286_179_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p227_019_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p248_025_pflow.wav
# ✅ Collected: 33800/40000, Trials: 34508
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p283_169_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p280_186_pflow.wav
# ✅ Collected: 33900/40000, Trials: 34610
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p306_205_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p292_122_pflow.wav
# ✅ Collected: 34000/40000, Trials: 34712
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p248_277_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p299_144_pflow.wav
# ✅ Collected: 34100/40000, Trials: 34814
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p228_083_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p241_077_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p318_286_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p297_249_pflow.wav
# ✅ Collected: 34200/40000, Trials: 34918
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p362_300_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p329_198_pflow.wav
# ✅ Collected: 34300/40000, Trials: 35020
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p248_277_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p263_217_pflow.wav
# ✅ Collected: 34400/40000, Trials: 35122
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p294_113_pflow.wav
# ✅ Collected: 34500/40000, Trials: 35223
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p266_133_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p227_157_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p274_216_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p232_062_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p298_048_pflow.wav
# ✅ Collected: 34600/40000, Trials: 35328
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p376_170_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p256_201_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p227_027_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p311_299_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p318_030_pflow.wav
# ✅ Collected: 34700/40000, Trials: 35433
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p316_282_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p333_049_pflow.wav
# ✅ Collected: 34800/40000, Trials: 35535
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p255_129_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p276_254_pflow.wav
# ✅ Collected: 34900/40000, Trials: 35637
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p248_109_pflow.wav
# ✅ Collected: 35000/40000, Trials: 35738
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p230_238_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p330_248_pflow.wav
# ✅ Collected: 35100/40000, Trials: 35840
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p260_244_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p277_289_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p306_194_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p298_140_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p360_199_pflow.wav
# ✅ Collected: 35200/40000, Trials: 35945
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p251_212_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p255_150_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p292_127_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p229_015_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p284_297_pflow.wav
# ✅ Collected: 35300/40000, Trials: 36050
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p263_006_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p225_043_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p227_232_pflow.wav
# ✅ Collected: 35400/40000, Trials: 36153
# ✅ Collected: 35500/40000, Trials: 36253
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p301_215_pflow.wav
# ✅ Collected: 35600/40000, Trials: 36354
# ✅ Collected: 35700/40000, Trials: 36454
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p305_135_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p374_185_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p280_204_pflow.wav
# ✅ Collected: 35800/40000, Trials: 36557
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p347_242_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p298_248_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p256_137_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p248_018_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p323_161_pflow.wav
# ✅ Collected: 35900/40000, Trials: 36662
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p335_190_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p293_183_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p281_251_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p271_154_pflow.wav
# ✅ Collected: 36000/40000, Trials: 36766
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p301_128_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p334_004_pflow.wav
# ✅ Collected: 36100/40000, Trials: 36868
# ✅ Collected: 36200/40000, Trials: 36968
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p318_068_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p341_067_pflow.wav
# ✅ Collected: 36300/40000, Trials: 37070
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p363_028_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p303_127_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p333_004_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p238_001_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p245_198_pflow.wav
# ✅ Collected: 36400/40000, Trials: 37175
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p237_276_pflow.wav
# ✅ Collected: 36500/40000, Trials: 37276
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p263_021_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p301_107_pflow.wav
# ✅ Collected: 36600/40000, Trials: 37379
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p307_202_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p272_232_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p258_269_pflow.wav
# ✅ Collected: 36700/40000, Trials: 37482
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p244_247_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p238_165_pflow.wav
# ✅ Collected: 36800/40000, Trials: 37584
# ✅ Collected: 36900/40000, Trials: 37684
# ✅ Collected: 37000/40000, Trials: 37784
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p286_235_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p330_177_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p343_128_pflow.wav
# ✅ Collected: 37100/40000, Trials: 37887
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p303_083_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p284_071_pflow.wav
# ✅ Collected: 37200/40000, Trials: 37989
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p330_216_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p243_213_pflow.wav
# ✅ Collected: 37300/40000, Trials: 38091
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p265_082_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p343_227_pflow.wav
# ✅ Collected: 37400/40000, Trials: 38193
# ✅ Collected: 37500/40000, Trials: 38293
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p272_234_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p310_146_pflow.wav
# ✅ Collected: 37600/40000, Trials: 38395
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p310_075_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p316_002_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p364_266_pflow.wav
# ✅ Collected: 37700/40000, Trials: 38498
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p361_288_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p343_250_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p262_253_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p225_149_pflow.wav
# ✅ Collected: 37800/40000, Trials: 38602
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p351_192_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p300_210_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p287_238_pflow.wav
# ✅ Collected: 37900/40000, Trials: 38705
# ✅ Collected: 38000/40000, Trials: 38805
# ✅ Collected: 38100/40000, Trials: 38905
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p246_264_pflow.wav
# ✅ Collected: 38200/40000, Trials: 39006
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p286_148_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p374_299_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p374_171_pflow.wav
# ✅ Collected: 38300/40000, Trials: 39109
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p374_191_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p280_038_pflow.wav
# ✅ Collected: 38400/40000, Trials: 39211
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p329_133_pflow.wav
# ✅ Collected: 38500/40000, Trials: 39312
# ✅ Collected: 38600/40000, Trials: 39412
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p264_033_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p306_269_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p226_112_pflow.wav
# ✅ Collected: 38700/40000, Trials: 39515
# ✅ Collected: 38800/40000, Trials: 39615
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p251_182_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p272_006_pflow.wav
# ✅ Collected: 38900/40000, Trials: 39717
# ✅ Collected: 39000/40000, Trials: 39817
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p323_161_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p301_083_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p292_240_pflow.wav
# ✅ Collected: 39100/40000, Trials: 39920
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p330_133_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p334_128_pflow.wav
# ✅ Collected: 39200/40000, Trials: 40022
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p284_287_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p241_232_pflow.wav
# ✅ Collected: 39300/40000, Trials: 40124
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p256_235_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p273_278_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p275_039_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p330_135_pflow.wav
# ✅ Collected: 39400/40000, Trials: 40228
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p250_083_pflow.wav
# ✅ Collected: 39500/40000, Trials: 40329
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p269_245_pflow.wav
# ✅ Collected: 39600/40000, Trials: 40430
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p292_242_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p303_171_pflow.wav
# ✅ Collected: 39700/40000, Trials: 40532
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p310_087_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p318_066_pflow.wav
# ✅ Collected: 39800/40000, Trials: 40634
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p315_104_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p363_026_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p258_128_pflow.wav
# ✅ Collected: 39900/40000, Trials: 40737
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p343_252_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p255_025_pflow.wav
# ❌ Error with F:\Deepfake-Audio-Detector\datasets\dfadd-dataset\fake\p231_139_pflow.wav
# ✅ Collected: 40000/40000, Trials: 40840
#
# 🎯 Done! Collected 40000 audio segments out of 40840 trials.

# %%
train_needed = count_audio_needed_for_balance("train")
val_needed = count_audio_needed_for_balance("val")
test_needed = count_audio_needed_for_balance("test")

DESTINATION_DIR = "F:\\Deepfake-Audio-Detector\\datasets\\raw_final_dataset"
SOURCE_DIR = "F:\\Deepfake-Audio-Detector\\datasets\\dfadd-standardized"

files = os.listdir(SOURCE_DIR)
random.shuffle(files)

total_needed = train_needed + val_needed + test_needed #type: ignore
assert total_needed <= len(files), "Not enough files to split!"

train_files = files[:train_needed]
val_files = files[train_needed : train_needed + val_needed]  # type: ignore
test_files = files[train_needed + val_needed : train_needed + val_needed + test_needed]  # type: ignore

train_output_dir = os.path.join(DESTINATION_DIR, "train", "fake")
val_output_dir = os.path.join(DESTINATION_DIR, "val", "fake")
test_output_dir = os.path.join(DESTINATION_DIR, "test", "fake")

for file in train_files:
    shutil.move(os.path.join(SOURCE_DIR, file), train_output_dir)
for file in val_files:
    shutil.move(os.path.join(SOURCE_DIR, file), val_output_dir)
for file in test_files:
    shutil.move(os.path.join(SOURCE_DIR, file), test_output_dir)
# Out:
# TRAIN \ real	: 51448 files
# TRAIN \ fake	: 20439 files
# Need 31009 to balance TRAIN data
# VAL \ real	: 3498 files
# VAL \ fake	: 1216 files
# Need 2282 to balance VAL data
# TEST \ real	: 7033 files
# TEST \ fake	: 2370 files
# Need 4663 to balance TEST data

# %%
SOURCE_DIR = "F:\\Deepfake-Audio-Detector\\datasets\\raw_final_dataset"

for set_type in ["train", "test", "val"]:
    extra_file = len([f for f in os.listdir(os.path.join(SOURCE_DIR, set_type)) if f.endswith('.wav')])
    fake_file = len(os.listdir(os.path.join(SOURCE_DIR, set_type, "fake")))
    real_file = len(os.listdir(os.path.join(SOURCE_DIR, set_type, "real"))) 
    n_fake_file = extra_file + fake_file
    print(f"\n{set_type.upper()} have {real_file} real_file and {n_fake_file} fake_file")
    print(f"Need {real_file - n_fake_file} to balance")
# Out:
# TRAIN have 51448 real_file and 51448 fake_file
# Need 0 to balance
#
# TEST have 7033 real_file and 7033 fake_file
# Need 0 to balance
#
# VAL have 3498 real_file and 3498 fake_file
# Need 0 to balance

# %%
SOURCE_DIR = "F:\\Deepfake-Audio-Detector\\datasets\\raw_final_dataset"

for set_type in ["train", "test", "val"]:
    source_dir = os.path.join(SOURCE_DIR, set_type)
    destination_path = os.path.join(source_dir, "fake")
    
    file_names = [f for f in os.listdir(source_dir)
                  if f.endswith('.wav') and os.path.isfile(os.path.join(source_dir, f))]

    for file_name in file_names:
        file_path = os.path.join(source_dir, file_name)
        shutil.move(file_path, destination_path)

    print(f"Done move file in {set_type}")
# Out:
# Done move file in {set_type}
# Done move file in {set_type}
# Done move file in {set_type}

# %%
SOURCE_DIR = "F:\\Deepfake-Audio-Detector\\datasets\\raw_final_dataset"

for set_type in ["train", "test", "val"]:
    fake_file = len(os.listdir(os.path.join(SOURCE_DIR, set_type, "fake")))
    real_file = len(os.listdir(os.path.join(SOURCE_DIR, set_type, "real")))
    print(
        f"\n{set_type.upper()} have {real_file} real_file and {fake_file} fake_file"
    )
# Out:
# TRAIN have 51448 real_file and 51448 fake_file
#
# TEST have 7033 real_file and 7033 fake_file
#
# VAL have 3498 real_file and 3498 fake_file
