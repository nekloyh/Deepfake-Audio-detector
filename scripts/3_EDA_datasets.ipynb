# %%
import os
import librosa  # Thư viện để tải và phân tích âm thanh
import numpy as np  # Để xử lý mảng số học
import pandas as pd  # Để tạo báo cáo CSV
import matplotlib.pyplot as plt  # Để vẽ biểu đồ

# %%
DATASET_ROOT_DIR = "F:\\Deepfake-Audio-Detector\\datasets\\for-dataset\\"
MIN_DURATION_THRESHOLD_SEC = 1.0
AUDIO_FILE_EXTENSIONS = [".wav", ".flac", ".mp3", ".m4a"] 

# --- Thực hiện EDA thời lượng âm thanh ---
durations = []
audio_file_info_list = []
failed_to_process = []

print(f"Bắt đầu quét dataset và phân tích thời lượng âm thanh từ thư mục: {DATASET_ROOT_DIR}")
print(f"Ngưỡng thời lượng tối thiểu cho file 'ngắn': {MIN_DURATION_THRESHOLD_SEC} giây.")
# Out:
# Bắt đầu quét dataset và phân tích thời lượng âm thanh từ thư mục: F:\Deepfake-Audio-Detector\datasets\for-dataset\
# Ngưỡng thời lượng tối thiểu cho file 'ngắn': 1.0 giây.

# %%
# Duyệt qua cấu trúc thư mục: <root>/<split>/<label>/<audio_file>
for split_type in ["train", "val", "test"]:
    split_path = os.path.join(DATASET_ROOT_DIR, split_type)
    
    if not os.path.isdir(split_path):
        print(f"Cảnh báo: Thư mục split '{split_path}' không tồn tại. Bỏ qua.")
        continue

    for label_type in ["fake", "real"]:
        label_path = os.path.join(split_path, label_type)
        if not os.path.isdir(label_path):
            print(f"Cảnh báo: Thư mục label '{label_path}' không tồn tại. Bỏ qua.")
            continue

        print(f"Đang quét thư mục: {label_path}")
        for filename in os.listdir(label_path):
            file_path = os.path.join(label_path, filename)

            if os.path.isfile(file_path) and any(filename.lower().endswith(ext) for ext in AUDIO_FILE_EXTENSIONS):
                try:
                    # Lấy thời lượng của file âm thanh mà không cần tải toàn bộ dữ liệu
                    duration = librosa.get_duration(path=file_path)
                    durations.append(duration)

                    # Trích xuất utterance_id từ tên file (bỏ phần mở rộng)
                    utterance_id = filename.split(".")[0]
                    utterance_id = utterance_id[4:]

                    file_info = {
                        "utterance_id": utterance_id,
                        "file_path": file_path,
                        "split": split_type,
                        "label": label_type,
                        "duration_sec": duration,
                    }
                    audio_file_info_list.append(file_info)

                except Exception as e:
                    print(f"Lỗi khi xử lý file {file_path}: {e}. Bỏ qua.")
                    failed_to_process.append(file_path)
            else:
                pass
# Out:
# Đang quét thư mục: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake
# Đang quét thư mục: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\real
# Đang quét thư mục: F:\Deepfake-Audio-Detector\datasets\for-dataset\val\fake
# Đang quét thư mục: F:\Deepfake-Audio-Detector\datasets\for-dataset\val\real
# Đang quét thư mục: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake
# Đang quét thư mục: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\real

# %%
HISTOGRAM_BIN_SIZE = 0.5
MIN_PLOT_DURATION_SEC = 0.0  # Change this to 'a'
MAX_PLOT_DURATION_SEC = 30.0

print("\n--- Kết quả EDA thời lượng âm thanh ---")
if audio_file_info_list:
    # Chuyển đổi danh sách thông tin file thành DataFrame để dễ phân tích
    df_eda = pd.DataFrame(audio_file_info_list)

    durations_np = df_eda["duration_sec"].values
    print(f"Tổng số file âm thanh đã phân tích thành công: {len(durations_np)}")
    print(f"Thời lượng trung bình: {np.mean(durations_np):.2f} giây")
    print(f"Thời lượng tối thiểu: {np.min(durations_np):.2f} giây")
    print(f"Thời lượng tối đa: {np.max(durations_np):.2f} giây")
    print(f"Thời lượng trung vị: {np.median(durations_np):.2f} giây")
    print(f"Độ lệch chuẩn thời lượng: {np.std(durations_np):.2f} giây")

    # Lọc và hiển thị các file ngắn
    short_audio_files_df = df_eda[df_eda["duration_sec"] < MIN_DURATION_THRESHOLD_SEC]
    print(f"\n--- Các file dưới {MIN_DURATION_THRESHOLD_SEC} giây ---")
    if not short_audio_files_df.empty:
        print(
            f"Tổng số file dưới {MIN_DURATION_THRESHOLD_SEC} giây: {len(short_audio_files_df)}"
        )
        for index, row in short_audio_files_df.iterrows():
            print(
                f"  ID: {row['utterance_id']}, Split: {row['split']}, Label: {row['label']}, Thời lượng: {row['duration_sec']:.2f} giây, Đường dẫn: {row['file_path']}"
            )

        # Lưu báo cáo file ngắn vào CSV
        short_audio_files_df.to_csv("3_short_audio_files_report.csv", index=False)
        print(
            "\nChi tiết các file ngắn đã được lưu vào '3_short_audio_files_report.csv'."
        )
    else:
        print(f"Không có file nào dưới {MIN_DURATION_THRESHOLD_SEC} giây.")

    # Hiển thị số lượng file theo split và label
    print("\n--- Thống kê số lượng file theo Split và Label ---")
    print(df_eda.groupby(["split", "label"]).size().unstack(fill_value=0))

    # --- Vẽ biểu đồ Histogram thời lượng cho từng loại split ---
    print("\n--- Đang vẽ biểu đồ Histogram thời lượng ---")

    unique_splits = df_eda["split"].unique()

    # Định nghĩa bins dựa trên khoảng MIN_PLOT_DURATION_SEC và MAX_PLOT_DURATION_SEC
    # Đảm bảo bins bao gồm cả MAX_PLOT_DURATION_SEC
    bins = np.arange(
        MIN_PLOT_DURATION_SEC,
        MAX_PLOT_DURATION_SEC + HISTOGRAM_BIN_SIZE,
        HISTOGRAM_BIN_SIZE,
    )

    for split_type in ["train", "val", "test"]:  # Đảm bảo thứ tự cố định
        if split_type in unique_splits:
            # Lọc dữ liệu cho từng loại split
            split_durations = df_eda[df_eda["split"] == split_type]["duration_sec"]

            plt.figure(figsize=(20, 6))  # Tạo một figure mới cho mỗi biểu đồ
            plt.hist(split_durations, bins=bins, edgecolor="black", alpha=0.7)
            plt.title(f"Phân phối thời lượng âm thanh - Tập {split_type.capitalize()}")
            plt.xlabel("Thời lượng (giây)")
            plt.ylabel("Số lượng file")
            plt.grid(axis="y", alpha=0.75)
            plt.xticks(rotation=45)  # Xoay nhãn trục x để dễ đọc

            # Đặt giới hạn trục X cho biểu đồ
            plt.xlim(MIN_PLOT_DURATION_SEC, MAX_PLOT_DURATION_SEC)

            plt.tight_layout()  # Điều chỉnh layout để tránh chồng lấn
            plt.show()
        else:
            print(f"Không có dữ liệu cho tập '{split_type}'. Bỏ qua vẽ biểu đồ.")

else:
    print("Không có file âm thanh nào được tìm thấy hoặc phân tích thành công.")

if failed_to_process:
    print(f"\n--- Các file không thể xử lý ---")
    print(f"Tổng số file không thể xử lý: {len(failed_to_process)}")
    for f_path in failed_to_process:
        print(f"  {f_path}")

print("\nQuá trình EDA thời lượng hoàn tất.")
# Out:
# --- Kết quả EDA thời lượng âm thanh ---
# Tổng số file âm thanh đã phân tích thành công: 97425
# Thời lượng trung bình: 3.60 giây
# Thời lượng tối thiểu: 0.00 giây
# Thời lượng tối đa: 39.81 giây
# Thời lượng trung vị: 2.72 giây
# Độ lệch chuẩn thời lượng: 2.38 giây
#
# --- Các file dưới 1.0 giây ---
# Tổng số file dưới 1.0 giây: 3860
#   ID: 100, Split: train, Label: fake, Thời lượng: 0.70 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file100.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10003, Split: train, Label: fake, Thời lượng: 0.98 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10003.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10014, Split: train, Label: fake, Thời lượng: 0.89 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10014.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1002, Split: train, Label: fake, Thời lượng: 0.89 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1002.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10040, Split: train, Label: fake, Thời lượng: 0.81 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10040.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10042, Split: train, Label: fake, Thời lượng: 0.75 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10042.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10043, Split: train, Label: fake, Thời lượng: 0.99 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10043.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10060, Split: train, Label: fake, Thời lượng: 0.86 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10060.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10063, Split: train, Label: fake, Thời lượng: 0.38 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10063.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10074, Split: train, Label: fake, Thời lượng: 0.86 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10074.wav
#   ID: 10074, Split: train, Label: fake, Thời lượng: 0.70 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10074.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10076, Split: train, Label: fake, Thời lượng: 0.94 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10076.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10078, Split: train, Label: fake, Thời lượng: 0.94 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10078.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10095, Split: train, Label: fake, Thời lượng: 0.73 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10095.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10103, Split: train, Label: fake, Thời lượng: 0.95 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10103.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10118, Split: train, Label: fake, Thời lượng: 0.95 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10118.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1013, Split: train, Label: fake, Thời lượng: 0.93 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1013.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10132, Split: train, Label: fake, Thời lượng: 0.97 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10132.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10135, Split: train, Label: fake, Thời lượng: 0.82 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10135.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10144, Split: train, Label: fake, Thời lượng: 0.79 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10144.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10145, Split: train, Label: fake, Thời lượng: 0.91 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10145.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1015, Split: train, Label: fake, Thời lượng: 0.86 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1015.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10159, Split: train, Label: fake, Thời lượng: 0.95 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10159.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10193, Split: train, Label: fake, Thời lượng: 0.98 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10193.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1020, Split: train, Label: fake, Thời lượng: 0.89 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1020.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1020, Split: train, Label: fake, Thời lượng: 0.91 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1020.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10200, Split: train, Label: fake, Thời lượng: 0.90 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10200.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10202, Split: train, Label: fake, Thời lượng: 0.82 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10202.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10204, Split: train, Label: fake, Thời lượng: 0.98 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10204.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10213, Split: train, Label: fake, Thời lượng: 0.77 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10213.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10216, Split: train, Label: fake, Thời lượng: 0.72 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10216.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10223, Split: train, Label: fake, Thời lượng: 0.85 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10223.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10239, Split: train, Label: fake, Thời lượng: 0.95 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10239.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10244, Split: train, Label: fake, Thời lượng: 0.74 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10244.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10247, Split: train, Label: fake, Thời lượng: 0.92 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10247.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10278, Split: train, Label: fake, Thời lượng: 0.96 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10278.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1028, Split: train, Label: fake, Thời lượng: 0.91 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1028.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10281, Split: train, Label: fake, Thời lượng: 0.93 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10281.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10285, Split: train, Label: fake, Thời lượng: 0.85 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10285.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10293, Split: train, Label: fake, Thời lượng: 0.98 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10293.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10296, Split: train, Label: fake, Thời lượng: 0.82 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10296.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10308, Split: train, Label: fake, Thời lượng: 0.69 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10308.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10312, Split: train, Label: fake, Thời lượng: 0.93 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10312.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10317, Split: train, Label: fake, Thời lượng: 0.99 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10317.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10318, Split: train, Label: fake, Thời lượng: 0.91 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10318.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10319, Split: train, Label: fake, Thời lượng: 0.92 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10319.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10322, Split: train, Label: fake, Thời lượng: 0.61 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10322.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1033, Split: train, Label: fake, Thời lượng: 0.62 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1033.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10356, Split: train, Label: fake, Thời lượng: 0.94 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10356.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10364, Split: train, Label: fake, Thời lượng: 0.51 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10364.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10366, Split: train, Label: fake, Thời lượng: 1.00 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10366.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10367, Split: train, Label: fake, Thời lượng: 0.79 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10367.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10370, Split: train, Label: fake, Thời lượng: 0.77 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10370.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10375, Split: train, Label: fake, Thời lượng: 0.87 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10375.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10396, Split: train, Label: fake, Thời lượng: 0.70 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10396.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10403, Split: train, Label: fake, Thời lượng: 0.74 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10403.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1041, Split: train, Label: fake, Thời lượng: 0.44 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1041.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10410, Split: train, Label: fake, Thời lượng: 0.48 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10410.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10424, Split: train, Label: fake, Thời lượng: 0.88 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10424.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10426, Split: train, Label: fake, Thời lượng: 0.83 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10426.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1043, Split: train, Label: fake, Thời lượng: 0.98 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1043.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10453, Split: train, Label: fake, Thời lượng: 0.56 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10453.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10458, Split: train, Label: fake, Thời lượng: 0.85 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10458.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10464, Split: train, Label: fake, Thời lượng: 0.91 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10464.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10489, Split: train, Label: fake, Thời lượng: 0.77 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10489.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1049, Split: train, Label: fake, Thời lượng: 0.76 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1049.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10494, Split: train, Label: fake, Thời lượng: 0.77 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10494.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10496, Split: train, Label: fake, Thời lượng: 0.73 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10496.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10499, Split: train, Label: fake, Thời lượng: 0.71 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10499.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 105, Split: train, Label: fake, Thời lượng: 0.76 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file105.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10509, Split: train, Label: fake, Thời lượng: 0.95 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10509.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10510, Split: train, Label: fake, Thời lượng: 0.96 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10510.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10517, Split: train, Label: fake, Thời lượng: 0.82 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10517.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10538, Split: train, Label: fake, Thời lượng: 0.92 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10538.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10539, Split: train, Label: fake, Thời lượng: 0.93 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10539.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10542, Split: train, Label: fake, Thời lượng: 0.27 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10542.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10556, Split: train, Label: fake, Thời lượng: 0.97 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10556.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10563, Split: train, Label: fake, Thời lượng: 0.98 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10563.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10566, Split: train, Label: fake, Thời lượng: 0.82 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10566.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10573, Split: train, Label: fake, Thời lượng: 0.87 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10573.wav
#   ID: 10573, Split: train, Label: fake, Thời lượng: 0.60 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10573.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10582, Split: train, Label: fake, Thời lượng: 0.95 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10582.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 106, Split: train, Label: fake, Thời lượng: 0.88 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file106.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10605, Split: train, Label: fake, Thời lượng: 0.98 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10605.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10620, Split: train, Label: fake, Thời lượng: 0.95 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10620.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10624, Split: train, Label: fake, Thời lượng: 0.96 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10624.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10630, Split: train, Label: fake, Thời lượng: 0.77 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10630.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10646, Split: train, Label: fake, Thời lượng: 0.85 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10646.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10674, Split: train, Label: fake, Thời lượng: 0.92 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10674.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10680, Split: train, Label: fake, Thời lượng: 0.81 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10680.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10685, Split: train, Label: fake, Thời lượng: 0.92 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10685.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10687, Split: train, Label: fake, Thời lượng: 0.67 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10687.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10703, Split: train, Label: fake, Thời lượng: 0.93 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10703.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10709, Split: train, Label: fake, Thời lượng: 0.95 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10709.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1073, Split: train, Label: fake, Thời lượng: 0.76 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1073.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10730, Split: train, Label: fake, Thời lượng: 0.93 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10730.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10758, Split: train, Label: fake, Thời lượng: 0.80 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10758.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10768, Split: train, Label: fake, Thời lượng: 0.89 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10768.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10773, Split: train, Label: fake, Thời lượng: 0.64 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10773.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10774, Split: train, Label: fake, Thời lượng: 0.89 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10774.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10776, Split: train, Label: fake, Thời lượng: 0.96 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10776.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10800, Split: train, Label: fake, Thời lượng: 0.70 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10800.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1082, Split: train, Label: fake, Thời lượng: 0.90 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1082.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10822, Split: train, Label: fake, Thời lượng: 0.72 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10822.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10858, Split: train, Label: fake, Thời lượng: 0.79 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10858.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10859, Split: train, Label: fake, Thời lượng: 0.84 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10859.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10862, Split: train, Label: fake, Thời lượng: 0.55 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10862.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10868, Split: train, Label: fake, Thời lượng: 0.98 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10868.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10869, Split: train, Label: fake, Thời lượng: 1.00 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10869.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10877, Split: train, Label: fake, Thời lượng: 0.97 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10877.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10893, Split: train, Label: fake, Thời lượng: 0.82 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10893.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10906, Split: train, Label: fake, Thời lượng: 0.99 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10906.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10914, Split: train, Label: fake, Thời lượng: 0.83 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10914.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10928, Split: train, Label: fake, Thời lượng: 0.51 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10928.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10935, Split: train, Label: fake, Thời lượng: 0.85 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10935.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10936, Split: train, Label: fake, Thời lượng: 0.72 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10936.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10951, Split: train, Label: fake, Thời lượng: 0.80 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10951.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10959, Split: train, Label: fake, Thời lượng: 0.91 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10959.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10961, Split: train, Label: fake, Thời lượng: 0.92 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10961.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10966, Split: train, Label: fake, Thời lượng: 0.66 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10966.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10987, Split: train, Label: fake, Thời lượng: 0.95 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file10987.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11, Split: train, Label: fake, Thời lượng: 0.70 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11039, Split: train, Label: fake, Thời lượng: 0.90 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11039.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1104, Split: train, Label: fake, Thời lượng: 0.76 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1104.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11044, Split: train, Label: fake, Thời lượng: 0.88 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11044.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11045, Split: train, Label: fake, Thời lượng: 0.68 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11045.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1105, Split: train, Label: fake, Thời lượng: 0.99 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1105.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11084, Split: train, Label: fake, Thời lượng: 0.89 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11084.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11088, Split: train, Label: fake, Thời lượng: 0.84 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11088.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11090, Split: train, Label: fake, Thời lượng: 0.57 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11090.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11093, Split: train, Label: fake, Thời lượng: 0.80 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11093.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11096, Split: train, Label: fake, Thời lượng: 0.77 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11096.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11102, Split: train, Label: fake, Thời lượng: 0.77 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11102.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11108, Split: train, Label: fake, Thời lượng: 0.99 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11108.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1111, Split: train, Label: fake, Thời lượng: 0.99 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1111.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11112, Split: train, Label: fake, Thời lượng: 0.89 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11112.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11117, Split: train, Label: fake, Thời lượng: 0.83 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11117.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11124, Split: train, Label: fake, Thời lượng: 1.00 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11124.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11138, Split: train, Label: fake, Thời lượng: 0.83 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11138.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11144, Split: train, Label: fake, Thời lượng: 0.51 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11144.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1115, Split: train, Label: fake, Thời lượng: 0.96 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1115.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11164, Split: train, Label: fake, Thời lượng: 0.82 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11164.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11169, Split: train, Label: fake, Thời lượng: 1.00 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11169.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11172, Split: train, Label: fake, Thời lượng: 0.72 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11172.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11180, Split: train, Label: fake, Thời lượng: 0.75 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11180.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11195, Split: train, Label: fake, Thời lượng: 0.64 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11195.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11196, Split: train, Label: fake, Thời lượng: 0.83 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11196.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11199, Split: train, Label: fake, Thời lượng: 0.93 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11199.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11208, Split: train, Label: fake, Thời lượng: 0.83 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11208.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11209, Split: train, Label: fake, Thời lượng: 0.93 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11209.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11228, Split: train, Label: fake, Thời lượng: 0.88 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11228.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11234, Split: train, Label: fake, Thời lượng: 0.83 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11234.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11239, Split: train, Label: fake, Thời lượng: 0.48 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11239.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11265, Split: train, Label: fake, Thời lượng: 0.62 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11265.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11268, Split: train, Label: fake, Thời lượng: 0.84 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11268.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11277, Split: train, Label: fake, Thời lượng: 0.74 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11277.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11285, Split: train, Label: fake, Thời lượng: 0.90 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11285.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11287, Split: train, Label: fake, Thời lượng: 0.87 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11287.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11323, Split: train, Label: fake, Thời lượng: 0.83 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11323.wav
#   ID: 11323, Split: train, Label: fake, Thời lượng: 0.69 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11323.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11338, Split: train, Label: fake, Thời lượng: 0.68 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11338.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11343, Split: train, Label: fake, Thời lượng: 0.76 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11343.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11351, Split: train, Label: fake, Thời lượng: 0.94 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11351.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11356, Split: train, Label: fake, Thời lượng: 0.71 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11356.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11359, Split: train, Label: fake, Thời lượng: 0.89 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11359.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11364, Split: train, Label: fake, Thời lượng: 0.85 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11364.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11367, Split: train, Label: fake, Thời lượng: 0.59 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11367.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1138, Split: train, Label: fake, Thời lượng: 0.63 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1138.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1138, Split: train, Label: fake, Thời lượng: 0.89 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1138.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11391, Split: train, Label: fake, Thời lượng: 0.93 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11391.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11407, Split: train, Label: fake, Thời lượng: 0.95 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11407.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1142, Split: train, Label: fake, Thời lượng: 0.78 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1142.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11465, Split: train, Label: fake, Thời lượng: 0.93 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11465.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11504, Split: train, Label: fake, Thời lượng: 0.95 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11504.wav
#   ID: 11504, Split: train, Label: fake, Thời lượng: 0.83 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11504.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11507, Split: train, Label: fake, Thời lượng: 0.60 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11507.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11508, Split: train, Label: fake, Thời lượng: 0.91 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11508.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11513, Split: train, Label: fake, Thời lượng: 0.62 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11513.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11519, Split: train, Label: fake, Thời lượng: 0.77 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11519.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11524, Split: train, Label: fake, Thời lượng: 0.73 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11524.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11530, Split: train, Label: fake, Thời lượng: 0.95 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11530.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11538, Split: train, Label: fake, Thời lượng: 0.97 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11538.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11543, Split: train, Label: fake, Thời lượng: 0.97 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11543.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11560, Split: train, Label: fake, Thời lượng: 0.64 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11560.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11563, Split: train, Label: fake, Thời lượng: 0.95 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11563.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11573, Split: train, Label: fake, Thời lượng: 0.82 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11573.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11586, Split: train, Label: fake, Thời lượng: 0.70 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11586.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1159, Split: train, Label: fake, Thời lượng: 0.92 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1159.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1159, Split: train, Label: fake, Thời lượng: 0.84 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1159.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11600, Split: train, Label: fake, Thời lượng: 0.85 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11600.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1161, Split: train, Label: fake, Thời lượng: 0.89 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1161.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11620, Split: train, Label: fake, Thời lượng: 0.62 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11620.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11622, Split: train, Label: fake, Thời lượng: 0.93 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11622.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11623, Split: train, Label: fake, Thời lượng: 0.49 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11623.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11624, Split: train, Label: fake, Thời lượng: 0.91 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11624.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11630, Split: train, Label: fake, Thời lượng: 0.91 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11630.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11637, Split: train, Label: fake, Thời lượng: 0.69 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11637.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11638, Split: train, Label: fake, Thời lượng: 0.55 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11638.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11640, Split: train, Label: fake, Thời lượng: 0.98 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11640.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11643, Split: train, Label: fake, Thời lượng: 0.78 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11643.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11645, Split: train, Label: fake, Thời lượng: 0.80 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11645.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11648, Split: train, Label: fake, Thời lượng: 0.99 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11648.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11666, Split: train, Label: fake, Thời lượng: 0.73 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11666.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11668, Split: train, Label: fake, Thời lượng: 0.98 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11668.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11675, Split: train, Label: fake, Thời lượng: 0.97 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11675.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1168, Split: train, Label: fake, Thời lượng: 0.62 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1168.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11684, Split: train, Label: fake, Thời lượng: 0.82 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11684.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11723, Split: train, Label: fake, Thời lượng: 0.68 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11723.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11729, Split: train, Label: fake, Thời lượng: 0.89 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11729.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1175, Split: train, Label: fake, Thời lượng: 0.82 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1175.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11758, Split: train, Label: fake, Thời lượng: 0.91 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11758.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11762, Split: train, Label: fake, Thời lượng: 1.00 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11762.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11767, Split: train, Label: fake, Thời lượng: 0.95 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11767.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11782, Split: train, Label: fake, Thời lượng: 0.96 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11782.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11788, Split: train, Label: fake, Thời lượng: 0.94 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11788.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11805, Split: train, Label: fake, Thời lượng: 1.00 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11805.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11822, Split: train, Label: fake, Thời lượng: 0.79 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11822.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11862, Split: train, Label: fake, Thời lượng: 0.99 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11862.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11871, Split: train, Label: fake, Thời lượng: 0.91 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11871.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11881, Split: train, Label: fake, Thời lượng: 0.97 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11881.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11897, Split: train, Label: fake, Thời lượng: 0.74 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11897.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11903, Split: train, Label: fake, Thời lượng: 0.99 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11903.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11910, Split: train, Label: fake, Thời lượng: 0.98 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11910.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11918, Split: train, Label: fake, Thời lượng: 0.70 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11918.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11963, Split: train, Label: fake, Thời lượng: 0.79 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11963.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11983, Split: train, Label: fake, Thời lượng: 0.91 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11983.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11999, Split: train, Label: fake, Thời lượng: 0.70 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file11999.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1200, Split: train, Label: fake, Thời lượng: 0.97 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1200.wav
#   ID: 1200, Split: train, Label: fake, Thời lượng: 0.72 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1200.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 12001, Split: train, Label: fake, Thời lượng: 0.93 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file12001.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 12005, Split: train, Label: fake, Thời lượng: 0.99 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file12005.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1202, Split: train, Label: fake, Thời lượng: 0.91 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1202.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 12023, Split: train, Label: fake, Thời lượng: 0.76 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file12023.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 12027, Split: train, Label: fake, Thời lượng: 0.98 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file12027.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 12042, Split: train, Label: fake, Thời lượng: 0.70 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file12042.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1205, Split: train, Label: fake, Thời lượng: 0.94 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file1205.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 12052, Split: train, Label: fake, Thời lượng: 0.91 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file12052.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 12056, Split: train, Label: fake, Thời lượng: 0.96 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file12056.wav
#   ID: 12056, Split: train, Label: fake, Thời lượng: 0.82 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file12056.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 12060, Split: train, Label: fake, Thời lượng: 0.98 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file12060.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 12064, Split: train, Label: fake, Thời lượng: 0.91 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file12064.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 12066, Split: train, Label: fake, Thời lượng: 0.75 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file12066.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 12067, Split: train, Label: fake, Thời lượng: 0.91 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file12067.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 12077, Split: train, Label: fake, Thời lượng: 0.97 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file12077.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 12081, Split: train, Label: fake, Thời lượng: 0.60 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file12081.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 12082, Split: train, Label: fake, Thời lượng: 0.80 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file12082.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 12086, Split: train, Label: fake, Thời lượng: 0.98 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file12086.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 12090, Split: train, Label: fake, Thời lượng: 0.81 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file12090.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 12095, Split: train, Label: fake, Thời lượng: 0.90 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file12095.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 12103, Split: train, Label: fake, Thời lượng: 0.97 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file12103.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 12104, Split: train, Label: fake, Thời lượng: 0.85 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file12104.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 12110, Split: train, Label: fake, Thời lượng: 0.83 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file12110.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 12111, Split: train, Label: fake, Thời lượng: 0.62 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file12111.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 12123, Split: train, Label: fake, Thời lượng: 0.99 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file12123.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 12126, Split: train, Label: fake, Thời lượng: 0.68 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\train\fake\file12126.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# ...
#   ID: 23990, Split: val, Label: fake, Thời lượng: 0.94 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\val\fake\file23990.wav
#   ID: 2464, Split: val, Label: fake, Thời lượng: 0.92 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\val\fake\file2464.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 25796, Split: val, Label: fake, Thời lượng: 0.90 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\val\fake\file25796.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 27337, Split: val, Label: fake, Thời lượng: 0.99 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\val\fake\file27337.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 27581, Split: val, Label: fake, Thời lượng: 0.77 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\val\fake\file27581.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 286, Split: val, Label: fake, Thời lượng: 0.92 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\val\fake\file286.wav
#   ID: 29775, Split: val, Label: fake, Thời lượng: 0.88 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\val\fake\file29775.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 31761, Split: val, Label: fake, Thời lượng: 0.73 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\val\fake\file31761.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 33196, Split: val, Label: fake, Thời lượng: 0.98 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\val\fake\file33196.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 33211, Split: val, Label: fake, Thời lượng: 0.88 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\val\fake\file33211.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 3591, Split: val, Label: fake, Thời lượng: 0.65 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\val\fake\file3591.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 5360, Split: val, Label: fake, Thời lượng: 0.83 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\val\fake\file5360.wav
#   ID: 5412, Split: val, Label: fake, Thời lượng: 0.96 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\val\fake\file5412.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 7000, Split: val, Label: fake, Thời lượng: 0.78 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\val\fake\file7000.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 8051, Split: val, Label: fake, Thời lượng: 0.99 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\val\fake\file8051.wav
#   ID: 8327, Split: val, Label: fake, Thời lượng: 0.77 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\val\fake\file8327.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 14041, Split: val, Label: real, Thời lượng: 0.90 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\val\real\file14041.wav
#   ID: 10922, Split: test, Label: fake, Thời lượng: 0.99 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file10922.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 10984, Split: test, Label: fake, Thời lượng: 0.96 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file10984.wav
#   ID: 11046, Split: test, Label: fake, Thời lượng: 0.69 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file11046.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 11137, Split: test, Label: fake, Thời lượng: 0.85 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file11137.wav
#   ID: 11550, Split: test, Label: fake, Thời lượng: 0.47 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file11550.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 13097, Split: test, Label: fake, Thời lượng: 0.84 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file13097.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 13120, Split: test, Label: fake, Thời lượng: 0.67 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file13120.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 13662, Split: test, Label: fake, Thời lượng: 0.83 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file13662.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 13704, Split: test, Label: fake, Thời lượng: 0.99 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file13704.wav
#   ID: 13891, Split: test, Label: fake, Thời lượng: 0.84 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file13891.wav
#   ID: 13973, Split: test, Label: fake, Thời lượng: 0.78 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file13973.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 14334, Split: test, Label: fake, Thời lượng: 0.96 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file14334.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 14795, Split: test, Label: fake, Thời lượng: 0.99 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file14795.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 16008, Split: test, Label: fake, Thời lượng: 0.94 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file16008.wav
#   ID: 16765, Split: test, Label: fake, Thời lượng: 0.59 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file16765.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 18050, Split: test, Label: fake, Thời lượng: 1.00 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file18050.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 1810, Split: test, Label: fake, Thời lượng: 0.99 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file1810.wav
#   ID: 18107, Split: test, Label: fake, Thời lượng: 0.61 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file18107.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 18507, Split: test, Label: fake, Thời lượng: 0.67 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file18507.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 20419, Split: test, Label: fake, Thời lượng: 0.88 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file20419.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 20445, Split: test, Label: fake, Thời lượng: 0.76 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file20445.wav
#   ID: 21364, Split: test, Label: fake, Thời lượng: 0.84 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file21364.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 21540, Split: test, Label: fake, Thời lượng: 0.83 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file21540.wav
#   ID: 21715, Split: test, Label: fake, Thời lượng: 0.77 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file21715.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 22016, Split: test, Label: fake, Thời lượng: 0.78 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file22016.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 22380, Split: test, Label: fake, Thời lượng: 0.96 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file22380.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 23341, Split: test, Label: fake, Thời lượng: 0.68 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file23341.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 23440, Split: test, Label: fake, Thời lượng: 0.84 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file23440.wav
#   ID: 23651, Split: test, Label: fake, Thời lượng: 0.57 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file23651.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 23866, Split: test, Label: fake, Thời lượng: 0.96 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file23866.wav
#   ID: 23956, Split: test, Label: fake, Thời lượng: 0.92 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file23956.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 24138, Split: test, Label: fake, Thời lượng: 0.64 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file24138.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 24297, Split: test, Label: fake, Thời lượng: 0.87 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file24297.wav
#   ID: 25060, Split: test, Label: fake, Thời lượng: 0.94 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file25060.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 25595, Split: test, Label: fake, Thời lượng: 0.90 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file25595.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 25774, Split: test, Label: fake, Thời lượng: 0.94 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file25774.wav
#   ID: 27740, Split: test, Label: fake, Thời lượng: 0.78 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file27740.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 27997, Split: test, Label: fake, Thời lượng: 0.98 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file27997.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 2827, Split: test, Label: fake, Thời lượng: 0.85 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file2827.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 28712, Split: test, Label: fake, Thời lượng: 0.88 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file28712.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 28783, Split: test, Label: fake, Thời lượng: 0.96 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file28783.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 29116, Split: test, Label: fake, Thời lượng: 0.87 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file29116.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 29306, Split: test, Label: fake, Thời lượng: 0.76 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file29306.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 29572, Split: test, Label: fake, Thời lượng: 0.99 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file29572.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 29666, Split: test, Label: fake, Thời lượng: 0.82 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file29666.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 30114, Split: test, Label: fake, Thời lượng: 0.98 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file30114.wav
#   ID: 30623, Split: test, Label: fake, Thời lượng: 0.99 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file30623.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 3069, Split: test, Label: fake, Thời lượng: 0.99 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file3069.wav
#   ID: 31289, Split: test, Label: fake, Thời lượng: 0.35 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file31289.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 31915, Split: test, Label: fake, Thời lượng: 0.98 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file31915.wav
#   ID: 32168, Split: test, Label: fake, Thời lượng: 0.90 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file32168.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 32692, Split: test, Label: fake, Thời lượng: 0.96 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file32692.wav
#   ID: 32817, Split: test, Label: fake, Thời lượng: 0.98 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file32817.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 32847, Split: test, Label: fake, Thời lượng: 0.80 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file32847.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 33015, Split: test, Label: fake, Thời lượng: 0.97 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file33015.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 33593, Split: test, Label: fake, Thời lượng: 0.64 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file33593.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 4338, Split: test, Label: fake, Thời lượng: 0.90 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file4338.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 5205, Split: test, Label: fake, Thời lượng: 0.52 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file5205.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 6598, Split: test, Label: fake, Thời lượng: 0.90 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file6598.wav
#   ID: 6629, Split: test, Label: fake, Thời lượng: 0.90 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file6629.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 6833, Split: test, Label: fake, Thời lượng: 0.74 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file6833.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 6921, Split: test, Label: fake, Thời lượng: 0.53 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file6921.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 7015, Split: test, Label: fake, Thời lượng: 0.85 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file7015.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 7239, Split: test, Label: fake, Thời lượng: 0.81 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file7239.wav
#   ID: 8052, Split: test, Label: fake, Thời lượng: 0.97 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file8052.wav
#   ID: 8481, Split: test, Label: fake, Thời lượng: 0.92 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file8481.wav
#   ID: 8578, Split: test, Label: fake, Thời lượng: 0.81 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file8578.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 8752, Split: test, Label: fake, Thời lượng: 0.88 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file8752.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 9641, Split: test, Label: fake, Thời lượng: 0.88 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file9641.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 9677, Split: test, Label: fake, Thời lượng: 0.81 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file9677.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
#   ID: 974, Split: test, Label: fake, Thời lượng: 0.91 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\fake\file974.wav
#   ID: 31470, Split: test, Label: real, Thời lượng: 0.90 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\real\file31470.wav
#   ID: 31484, Split: test, Label: real, Thời lượng: 0.90 giây, Đường dẫn: F:\Deepfake-Audio-Detector\datasets\for-dataset\test\real\file31484.wav
#
# Chi tiết các file ngắn đã được lưu vào 'short_audio_files_report.csv'.
#
# --- Thống kê số lượng file theo Split và Label ---
# label   fake   real
# split
# test    2778   6768
# train  32976  50130
# val     1399   3374
#
# --- Đang vẽ biểu đồ Histogram thời lượng ---
# Quá trình EDA thời lượng hoàn tất.
